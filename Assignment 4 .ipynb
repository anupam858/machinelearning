# %% [markdown]
# # Day 4 Matplotlib
# q.
#
# 1. Plot a Bar Chart
# 2. Scatter
# 3. Histogram
# 4. box plot

# %%
from matplotlib import pyplot as plot
plot.rcParams["figure.figsize"] = (15,8)

# %%
# %run Asignment3.ipynb
# Out:
# [1500. 1900. 2100. 2300. 3900. 2010. 3200. 1400. 2100. 1900. 1700. 1300.
#  2200.]

# %%
print(array)
# Out:
# [[  800.   700.  1500.]
#  [ 1000.   900.  1900.]
#  [ 1100.  1000.  2100.]
#  [ 1200.  1100.  2300.]
#  [ 2000.  1900.  3900.]
#  [ 1010.  1000.  2010.]
#  [ 1600.  1600.  3200.]
#  [ 1400.     0.  1400.]
#  [ 1000.  1100.  2100.]
#  [  900.  1000.  1900.]
#  [  800.   900.  1700.]
#  [  600.   700.  1300.]
#  [  700.  1500.  2200.]
#  [14110. 13400. 27510.]]

# %%
company = comp_data['Company'].values
Sales = comp_data['Sales'].values

plot.bar(company,Sales, color = 'red')
plot.xlabel('Company')
plot.ylabel('Sales')
plot.title('Company Sales Plot')
# Out:
# Text(0.5,1,'Company Sales Plot')

# %%
plot.scatter(company,Sales, color='green')

# %%
plot.hist(Sales,facecolor='purple')
# Out:
# (array([2., 2., 4., 1., 1., 1., 0., 1., 0., 1.]),
#  array([ 600.,  740.,  880., 1020., 1160., 1300., 1440., 1580., 1720.,
#         1860., 2000.]),
#  <a list of 10 Patch objects>)

# %%
comp_data.boxplot(column='Sales', by='Company')

# %% [markdown]
# # Day 5
#
# 1. plot 3 graphs side by side.
# 2. Plot a grah inside another graph.

# %%
plot.subplot(2,2,1)
plot.bar(company,Sales, color = 'red')

plot.subplot(2,2,2)
plot.scatter(company,Sales, color='green')

plot.subplot(2,2,3)
plot.hist(Sales,facecolor='purple')

plot.subplot(2,2,4)
comp_data.boxplot(column='Sales', by='Company')

# %%
fig,graph1 = plot.subplots()

graph2 = fig.add_axes([.15, .65,.25,.25])
graph1.scatter(company,Sales, color='green')
graph2.hist(Sales,facecolor='purple')

plot.show()
